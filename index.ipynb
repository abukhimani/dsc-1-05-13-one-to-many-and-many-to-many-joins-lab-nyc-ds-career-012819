# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on One-to-Many and Many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data including Many-to-Many relationships
# - Write queries that make use of Join Tables

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='Database-Schema.png' width=550>

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('data.sqlite', detect_types=sqlite3.PARSE_COLNAMES)
cur = conn.cursor()

# %%
#Your code here
cur.execute('''SELECT firstName, lastName, city, state 
                    FROM employees JOIN offices ON employees.officeCode = offices.officeCode 
                    ORDER BY firstName ASC, lastName ASC;''')

# %%
cur.fetchall()
# Out:
# [('Andy', 'Fixter', 'Sydney', ''),
#  ('Anthony', 'Bow', 'San Francisco', 'CA'),
#  ('Barry', 'Jones', 'London', ''),
#  ('Diane', 'Murphy', 'San Francisco', 'CA'),
#  ('Foon Yue', 'Tseng', 'NYC', 'NY'),
#  ('George', 'Vanauf', 'NYC', 'NY'),
#  ('Gerard', 'Bondur', 'Paris', ''),
#  ('Gerard', 'Hernandez', 'Paris', ''),
#  ('Jeff', 'Firrelli', 'San Francisco', 'CA'),
#  ('Julie', 'Firrelli', 'Boston', 'MA'),
#  ('Larry', 'Bott', 'London', ''),
#  ('Leslie', 'Jennings', 'San Francisco', 'CA'),
#  ('Leslie', 'Thompson', 'San Francisco', 'CA'),
#  ('Loui', 'Bondur', 'Paris', ''),
#  ('Mami', 'Nishi', 'Tokyo', 'Chiyoda-Ku'),
#  ('Martin', 'Gerard', 'Paris', ''),
#  ('Mary', 'Patterson', 'San Francisco', 'CA'),
#  ('Pamela', 'Castillo', 'Paris', ''),
#  ('Peter', 'Marsh', 'Sydney', ''),
#  ('Steve', 'Patterson', 'Boston', 'MA'),
#  ('Tom', 'King', 'Sydney', ''),
#  ('William', 'Patterson', 'Sydney', ''),
#  ('Yoshimi', 'Kato', 'Tokyo', 'Chiyoda-Ku')]

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all of the customers. For each customer return a record for each of their order numbers, order dates and statuses.

# %%
# Your code here
cur.execute('''SELECT customerName, orderNumber, orderDate, status 
                FROM customers JOIN orders ON customers.customerNumber = orders.customerNumber;''')

# %%
df= pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df
# Out:
#                        customerName orderNumber   orderDate      status
# 0                 Atelier graphique       10123  2003-05-20     Shipped
# 1                 Atelier graphique       10298  2004-09-27     Shipped
# 2                 Atelier graphique       10345  2004-11-25     Shipped
# 3                Signal Gift Stores       10124  2003-05-21     Shipped
# 4                Signal Gift Stores       10278  2004-08-06     Shipped
# 5                Signal Gift Stores       10346  2004-11-29     Shipped
# 6        Australian Collectors, Co.       10120  2003-04-29     Shipped
# 7        Australian Collectors, Co.       10125  2003-05-21     Shipped
# 8        Australian Collectors, Co.       10223  2004-02-20     Shipped
# 9        Australian Collectors, Co.       10342  2004-11-24     Shipped
# 10       Australian Collectors, Co.       10347  2004-11-29     Shipped
# 11                La Rochelle Gifts       10275  2004-07-23     Shipped
# ...

# %% [markdown]
# ## Orders and their Order Details (another One-to-Many join)
#
# Return a list of orders. For each order return a record for each order detail within the order.

# %%
# Your code here
cur.execute('''SELECT * FROM orders JOIN orderdetails ON orders.orderNumber = orderdetails.orderNumber;''')

# %%
cur.fetchall()
# Out:
# [('10100',
#   '2003-01-06',
#   '2003-01-13',
#   '2003-01-10',
#   'Shipped',
#   '',
#   '363',
#   '10100',
#   'S18_1749',
#   '30',
#   '136.00',
#   '3'),
#  ('10100',
#   '2003-01-06',
#   '2003-01-13',
#   '2003-01-10',
#   'Shipped',
#   '',
#   '363',
#   '10100',
#   'S18_2248',
#   '50',
#   '55.09',
#   '2'),
#  ('10100',
#   '2003-01-06',
#   '2003-01-13',
#   '2003-01-10',
#   'Shipped',
#   '',
#   '363',
#   '10100',
#   'S18_4409',
#   '22',
#   '75.46',
#   '4'),
#  ('10100',
#   '2003-01-06',
#   '2003-01-13',
#   '2003-01-10',
#   'Shipped',
#   '',
#   '363',
#   '10100',
#   'S24_3969',
#   '49',
#   '35.29',
#   '1'),
#  ('10101',
#   '2003-01-09',
#   '2003-01-18',
#   '2003-01-11',
#   'Shipped',
#   'Check on availability.',
#   '128',
#   '10101',
#   'S18_2325',
#   '25',
#   '108.06',
#   '4'),
#  ('10101',
#   '2003-01-09',
#   '2003-01-18',
#   '2003-01-11',
#   'Shipped',
#   'Check on availability.',
#   '128',
#   '10101',
#   'S18_2795',
# ...

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of the orders with the the order information, and all the product information for each product in the order.

# %%
# Your code here
cur.execute('''SELECT * FROM orders JOIN orderdetails ON orders.orderNumber = orderdetails.orderNumber
                JOIN products ON products.productCode = orderdetails.productCode;''')

# %%
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]

# %%
df
# Out:
#      orderNumber   orderDate requiredDate shippedDate      status  \
# 0          10100  2003-01-06   2003-01-13  2003-01-10     Shipped
# 1          10100  2003-01-06   2003-01-13  2003-01-10     Shipped
# 2          10100  2003-01-06   2003-01-13  2003-01-10     Shipped
# 3          10100  2003-01-06   2003-01-13  2003-01-10     Shipped
# 4          10101  2003-01-09   2003-01-18  2003-01-11     Shipped
# 5          10101  2003-01-09   2003-01-18  2003-01-11     Shipped
# 6          10101  2003-01-09   2003-01-18  2003-01-11     Shipped
# 7          10101  2003-01-09   2003-01-18  2003-01-11     Shipped
# 8          10102  2003-01-10   2003-01-18  2003-01-14     Shipped
# 9          10102  2003-01-10   2003-01-18  2003-01-14     Shipped
# 10         10103  2003-01-29   2003-02-07  2003-02-02     Shipped
# 11         10103  2003-01-29   2003-02-07  2003-02-02     Shipped
# 12         10103  2003-01-29   2003-02-07  2003-02-02     Shipped
# ...

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on One-to-Many and Many-to-many relationships!
